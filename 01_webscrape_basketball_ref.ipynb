# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %% [markdown]
# # Webscraping Basketball Reference

# %% [markdown]
# ## Webscrape 1981

# %%
mvp_1981_url = 'https://www.basketball-reference.com/awards/awards_1981.html'
data_1981 = requests.get(mvp_1981_url)
with open('mvp/1981.html','w+') as f:
    f.write(data_1981.text)

# %% [markdown]
# ## Convert html file to pandas dataframe

# %%
with open('mvp/1981.html') as f:
    page_1981 = f.read()
soup = BeautifulSoup(page_1981,'html.parser')
soup.find('tr', class_= 'over_header').decompose()

# %%
mvp_1981_table = soup.find_all(id = 'mvp')[0]

# %%
mvp_1981 = pd.read_html(str(mvp_1981_table))[0]

# %%
mvp_1981
# Out:
#    Rank                  Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0     1           Julius Erving   30  PHI   28.0    454.0      690  0.658  82
# 1     2              Larry Bird   24  BOS   20.0    423.0      690  0.613  82
# 2     3     Kareem Abdul-Jabbar   33  LAL    8.0    286.0      690  0.414  80
# 3     4            Moses Malone   25  HOU    8.0    180.0      690  0.261  80
# 4     5           George Gervin   28  SAS    1.0     83.0      690  0.120  82
# 5     6         Marques Johnson   24  MIL    1.0     73.0      690  0.106  76
# 6     7           Robert Parish   27  BOS    0.0     53.0      690  0.077  82
# 7     8          Dennis Johnson   26  PHO    0.0     50.0      690  0.072  79
# 8     9          Tiny Archibald   32  BOS    0.0     32.0      690  0.046  80
# 9    10           Jamaal Wilkes   27  LAL    0.0     19.0      690  0.028  81
# 10   11           Magic Johnson   21  LAL    0.0     18.0      690  0.026  37
# 11  12T          Adrian Dantley   25  UTA    1.0     15.0      690  0.022  80
# 12  12T               Phil Ford   24  KCK    1.0     15.0      690  0.022  66
# 13   14            Bernard King   24  GSW    0.0     12.0      690  0.017  81
# 14  15T           Kelvin Ransey   22  POR    1.0     11.0      690  0.016  80
# 15  15T              Jack Sikma   25  SEA    0.0     11.0      690  0.016  82
# 16  17T           Otis Birdsong   25  KCK    0.0      7.0      690  0.010  71
# 17  17T  Micheal Ray Richardson   25  NYK    0.0      7.0      690  0.010  79
# 18  19T          Truck Robinson   29  PHO    0.0      6.0      690  0.009  82
# 19  19T            Reggie Theus   23  CHI    0.0      6.0      690  0.009  82
# 20   21              Norm Nixon   25  LAL    0.0      5.0      690  0.007  79
# 21  22T           Artis Gilmore   31  CHI    0.0      4.0      690  0.006  82
# 22  22T              Bob Lanier   32  MIL    0.0      4.0      690  0.006  67
# 23  24T          Michael Cooper   24  LAL    0.0      3.0      690  0.004  81
# 24  24T            Walter Davis   26  PHO    0.0      3.0      690  0.004  78
# 25  24T          George Johnson   32  SAS    0.0      3.0      690  0.004  82
# 26  24T             Bobby Jones   29  PHI    0.0      3.0      690  0.004  81
# 27  24T           Mike Mitchell   25  CLE    0.0      3.0      690  0.004  82
# 28  24T             James Silas   31  SAS    0.0      3.0      690  0.004  75
# 29  30T           Quinn Buckner   26  MIL    0.0      1.0      690  0.001  82
# 30  30T          Caldwell Jones   30  PHI    0.0      1.0      690  0.001  81
#
#       MP   PTS   TRB  AST  STL  BLK    FG%    3P%    FT%    WS  WS/48
# 0
player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0    1  Julius Erving   30  PHI   28.0    454.0      690  0.658  82  35.0
# 1    2     Larry Bird   24  BOS   20.0    423.0      690  0.613  82  39.5
#
#    ...   TRB  AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0  ...   8.0  4.4  2.1  1.8  0.521  0.222  0.787  13.8  0.231  1981
# 1  ...  10.9  5.5  2.0  0.8  0.478  0.270  0.863  10.8  0.160  1981
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Webscrape 1982-2022

# %%
years= list(range(1982,2023))

# %%
url_year_start = 'https://www.basketball-reference.com/awards/awards_{}.html'

for y in years:
    url = url_year_start.format(y)
    
    data = requests.get(url)
    
    with open(f"mvp/{y}.html","w+") as f:
        f.write(data.text)

# %% [markdown]
# ## Convert multiple files to dataframes

# %%
years= list(range(1981,2023))

# %%
data_frames = []
for y in years:
    with open (f'mvp/{y}.html') as f:
        page = f.read()
        
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_ = 'over_header').decompose()
    mvp_table = soup.find_all(id = 'mvp')[0]
    mvp_df = pd.read_html(str(mvp_table))[0]
    mvp_df["Year"] = y
    data_frames.append(mvp_df)

# %%
mvp_df = pd.concat(data_frames)

mvp_df.tail(3)
# Out:
#    Rank         Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 9   10T  DeMar DeRozan   32  CHI    0.0      1.0     1000  0.001  76  36.1
# 10  10T   Kevin Durant   33  BRK    0.0      1.0     1000  0.001  55  37.2
# 11  10T   LeBron James   37  LAL    0.0      1.0     1000  0.001  56  37.2
#
#     ...  TRB  AST  STL  BLK    FG%    3P%    FT%   WS  WS/48  Year
# 9   ...  5.2  4.9  0.9  0.3  0.504  0.352  0.877  8.8  0.154  2022
# 10  ...  7.4  6.4  0.9  0.9  0.518  0.383  0.910  8.4  0.198  2022
# 11  ...  8.2  6.2  1.3  1.1  0.524  0.359  0.756  7.5  0.172  2022
#
# [3 rows x 21 columns]

# %%
mvp_df.to_csv('data/mvp_df.csv', index=False)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome(
    executable_path='/Users/dcast822/chromedriver')
# Out:
# /var/folders/h9/gwl1hr8n5_x6kwzstxs78nx40000gn/T/ipykernel_23410/2533717168.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(

# %% [markdown]
# ## Get players

# %%
player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"
for year in years:
    url = player_stats_url.format(year)
    driver.get(url)
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(2)
    
    with open(f'player/{year}.html',"w+") as f:
        f.write(driver.page_source)

# %%
players = []
for year in years:
    with open(f'player/{year}.html') as f:
        page = f.read()
    soup = BeautifulSoup(page,'html.parser')
    soup.find('tr', class_ = 'thead').decompose()
    players_table = soup.find_all(id = "per_game_stats")[0]
    players_df = pd.read_html(str(players_table))[0]
    players_df["Year"] = year
    players.append(players_df)

# %%
player_df = pd.concat(players)

# %%
player_df.head()
# Out:
#   Rk                Player Pos Age   Tm   G   GS    MP    FG   FGA  ...  ORB  \
# 0  1  Kareem Abdul-Jabbar*   C  33  LAL  80  NaN  37.2  10.5  18.2  ...  2.5
# 1  2         Tom Abernethy  SF  26  TOT  39  NaN   7.6   0.6   1.5  ...  0.5
# 2  2         Tom Abernethy  SF  26  GSW  10  NaN   3.9   0.1   0.3  ...  0.1
# 3  2         Tom Abernethy  SF  26  IND  29  NaN   8.9   0.8   1.9  ...  0.7
# 4  3           Alvan Adams   C  26  PHO  75  NaN  27.4   6.1  11.6  ...  2.1
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  7.8  10.3  3.4  0.7  2.9  3.1  3.1  26.2  1981
# 1  0.7   1.2  0.5  0.2  0.1  0.2  0.9   1.6  1981
# 2  0.7   0.8  0.1  0.1  0.0  0.2  0.5   0.4  1981
# 3  0.7   1.4  0.6  0.2  0.1  0.2  1.0   2.0  1981
# 4  5.2   7.3  4.6  1.4  0.9  3.0  3.0  14.9  1981
#
# [5 rows x 31 columns]

# %%
player_df.to_csv("data/players.csv", index = False)

# %% [markdown]
# ## Get Team Data

# %%
teams_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"
for year in years:
    url = teams_url.format(year)
    data = requests.get(url)
    with open(f"team/{year}.html", "w+") as f:
        f.write(data.text)

# %%
team_dfs = []

for year in years:
    with open(f'team/{year}.html') as f:
        page = f.read()
    soup = BeautifulSoup(page,'html.parser')
    soup.find('tr', class_ = 'thead').decompose()
    east_table = soup.find_all(id = 'divs_standings_E')[0]
    east_df = pd.read_html(str(east_table))[0]
    east_df["Year"] = year
    east_df["Team"] = east_df["Eastern Conference"]
    del east_df["Eastern Conference"]
    team_dfs.append(east_df)
    
    west_table = soup.find_all(id = 'divs_standings_W')[0]
    west_df = pd.read_html(str(west_table))[0]
    west_df["Year"] = year
    west_df["Team"] = west_df["Western Conference"]
    del west_df["Western Conference"]
    team_dfs.append(west_df)

# %%
teams = pd.concat(team_dfs)

# %%
teams.head()
# Out:
#     W   L  W/L%    GB   PS/G   PA/G    SRS  Year                 Team
# 0  62  20  .756     —  109.9  104.0   6.05  1981      Boston Celtics*
# 1  62  20  .756     —  111.7  103.8   7.76  1981  Philadelphia 76ers*
# 2  50  32  .610  12.0  107.9  106.3   2.00  1981     New York Knicks*
# 3  39  43  .476  23.0  105.6  105.6   0.42  1981   Washington Bullets
# 4  24  58  .293  38.0  106.9  113.0  -5.15  1981      New Jersey Nets

# %%
teams.tail()
# Out:
#      W   L  W/L%    GB   PS/G   PA/G    SRS  Year                   Team
# 13  56  26  .683     —  115.6  109.9   5.37  2022     Memphis Grizzlies*
# 14  52  30  .634   4.0  108.0  104.7   3.12  2022      Dallas Mavericks*
# 15  36  46  .439  20.0  109.3  110.3  -0.84  2022  New Orleans Pelicans*
# 16  34  48  .415  22.0  113.2  113.0   0.02  2022      San Antonio Spurs
# 17  20  62  .244  36.0  109.7  118.2  -8.26  2022        Houston Rockets

# %%
teams.to_csv('data/teams.csv', index=False)
